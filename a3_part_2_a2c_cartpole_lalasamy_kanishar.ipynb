# %%
# !pip install gymnasium[box2d] matplotlib torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...

# %%
pip install swig
# Out:
# ...
#   Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# ...

# %%
pip install "gymnasium[box2d]"
# Out:
# ...
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379373 sha256=1cd902493376576f46699c93c875789456b9af404e6494c85dec844680cb4fd0
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# ...

# %%
# !python a3_part_2_a2c_cartpole_lalasamy_kanishar.py
# Out:
# Episode 50: Reward = 11.0
# Episode 100: Reward = 19.0
# Episode 150: Reward = 37.0
# Episode 200: Reward = 12.0
# Episode 250: Reward = 15.0
# Episode 300: Reward = 64.0
# Episode 350: Reward = 22.0
# Episode 400: Reward = 15.0
# Episode 450: Reward = 11.0
# Episode 500: Reward = 26.0
# Episode 550: Reward = 13.0
# Episode 600: Reward = 11.0
# Episode 650: Reward = 14.0
# Episode 700: Reward = 18.0
# Episode 750: Reward = 23.0
# Episode 800: Reward = 19.0
# Episode 850: Reward = 17.0
# Episode 900: Reward = 28.0
# Episode 950: Reward = 11.0
# Episode 1000: Reward = 28.0
# Episode 1050: Reward = 56.0
# Episode 1100: Reward = 18.0
# Episode 1150: Reward = 13.0
# Episode 1200: Reward = 22.0
# Episode 1250: Reward = 29.0
# Episode 1300: Reward = 32.0
# Episode 1350: Reward = 24.0
# Episode 1400: Reward = 19.0
# Episode 1450: Reward = 20.0
# Episode 1500: Reward = 59.0
# Episode 1550: Reward = 12.0
# Episode 1600: Reward = 19.0
# Episode 1650: Reward = 29.0
# Episode 1700: Reward = 48.0
# ...

# %%
import torch
from a3_part_2_a2c_cartpole_lalasamy_kanishar import ActorCritic, evaluate_policy

# %%
input_dim = 4
hidden_dim = 256
n_actions = 2
model = ActorCritic(input_dim, hidden_dim, n_actions)
model_path = "/content/models/a2c_cartpole_model.pth"
model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
model.eval()
evaluate_policy(model, env_name="CartPole-v1", n_episodes=10)
