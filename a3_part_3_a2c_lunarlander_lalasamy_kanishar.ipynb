# %%
# !pip install gymnasium[box2d] matplotlib torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...

# %%
pip install swig
# Out:
# ...
#   Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# ...

# %%
pip install "gymnasium[box2d]"
# Out:
# ...
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379369 sha256=41e8b8fea34e19969dfea67e9d3fb55bba1d5fb3a03c9255437be1ede74571d0
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# ...

# %%
# !python a3_part_2_a2c_lunarlander_lalasamy_kanishar.py
# Out:
# Episode 50: Reward = -120.98539205491979
# Episode 100: Reward = -368.8022858598439
# Episode 150: Reward = -241.97238546353918
# Episode 200: Reward = -77.36356853356212
# Episode 250: Reward = -187.34905638878325
# Episode 300: Reward = -304.5756558211709
# Episode 350: Reward = -311.1329559879347
# Episode 400: Reward = -342.9701850682373
# Episode 450: Reward = -70.49682197867205
# Episode 500: Reward = -295.738494889767
# [!] New best model saved at episode 500 with avg reward -223.87
# Episode 550: Reward = -65.67507784201916
# Episode 600: Reward = -203.7746976065502
# Episode 650: Reward = -171.78120230655082
# Episode 700: Reward = -197.44302320941074
# Episode 750: Reward = -233.033351087791
# Episode 800: Reward = -51.22921631532316
# Episode 850: Reward = -157.04044457899766
# Episode 900: Reward = -54.89091666035659
# Episode 950: Reward = -136.67868985338316
# Episode 1000: Reward = 43.688883458482394
# [!] New best model saved at episode 1000 with avg reward -205.64
# ...

# %%
import torch
import torch.nn as nn
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np

# %%
from a3_part_3_a2c_lunarlander_lalasamy_kanishar import ActorCritic, evaluate_policy

# %%
model = ActorCritic(8, 256, 4)
model.load_state_dict(torch.load("/content/models/best_model.pth", map_location=torch.device("cpu")))
model.eval()
# Out:
# ActorCritic(
#   (shared): Sequential(
#     (0): Linear(in_features=8, out_features=256, bias=True)
#     (1): ReLU()
#   )
#   (actor): Linear(in_features=256, out_features=4, bias=True)
#   (critic): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
evaluate_policy(model, env_name="LunarLander-v3", n_episodes=50)
